# %%
# Cell 1 — Setup for explainability
# %run ./00_config.ipynb

import os, torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# 1) Load best model + tokenizer
model_dir = cfg.paths.model_dir
tokenizer = AutoTokenizer.from_pretrained(model_dir)
model = AutoModelForSequenceClassification.from_pretrained(model_dir)
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device).eval()

print("✅ Model loaded for explainability")
print("Device:", device)
print("Labels:", list(cfg.labels))

# 2) Ensure SHAP is available
try:
    import shap
    print("SHAP version:", shap.__version__)
except Exception as e:
    print("SHAP not found. Installing…")
    import sys, subprocess
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "shap"])
    import shap
    print("SHAP version (after install):", shap.__version__)
# Out:
# Python version: 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
# CUDA available: False
# Running on CPU
# ../../data/train_data.csv
# microsoft/mdeberta-v3-base
# ✅ Config loaded and random seed set to: 42
# 📂 Model directory: ../models/best
# 📂 Reports directory: ../reports
# ✅ Folder setup complete.
# ✅ Found: ..\..\data\train_data.csv
# ✅ Found: ..\..\data\test_data.csv
#
# All required data files are present and accessible.
# ✅ Configuration snapshot saved at:
# ../reports\config_snapshot.json
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# ✅ Model loaded for explainability
# Device: cpu
# Labels: ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
# SHAP version: 0.49.1

# %%
# Cell 2 — SHAP text explainer for one label

import shap
import numpy as np
import os

# 1) choose which label to explain (you can change this)
label_to_explain = "toxic"   # e.g., "insult", "obscene", etc.
label_idx = list(cfg.labels).index(label_to_explain)
print("Explaining label:", label_to_explain, "→ index", label_idx)

# 2) small background texts to speed up SHAP on CPU
background_texts = [
    "Have a nice day.",
    "I disagree with your point.",
    "This is helpful, thank you.",
    "Please keep the discussion civil.",
    "I don't think that's correct."
]

# 3) prediction function returning probabilities for the chosen label
def f_label(texts):
    if isinstance(texts, str):
        texts = [texts]
    with torch.no_grad():
        enc = tokenizer(
            list(texts),
            truncation=True,
            padding=True,
            max_length=min(128, cfg.train.max_len),
            return_tensors="pt"
        ).to(model.device)
        probs = torch.sigmoid(model(**enc).logits).detach().cpu().numpy()
    # return the column for the selected label as a 1D vector
    return probs[:, label_idx]

# 4) create a text masker and explainer
masker = shap.maskers.Text(tokenizer)  # SHAP will tokenize and mask words/subwords
explainer = shap.Explainer(f_label, masker)

print("✅ SHAP explainer ready for label:", label_to_explain)
# Out:
# Explaining label: toxic → index 0
# WARNING:tensorflow:From c:\Users\alaud\AppData\Local\Programs\Python\Python313\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ✅ SHAP explainer ready for label: toxic

# %%
# Cell 4 — Batch SHAP gallery (RED = pushes up → more toxic, BLUE = pushes down → less toxic)
# Requires: tokenizer, model, explainer, label_to_explain, label_idx, and a renderer

import os, torch, numpy as np, pandas as pd
from IPython.display import HTML, display

gallery_dir = os.path.join(cfg.paths.reports_dir, "figs", f"shap_gallery_{label_to_explain}")
os.makedirs(gallery_dir, exist_ok=True)

# ---------- choose inputs ----------
USE_TOP_FROM_VAL = 'val_df' in globals()  # if val_df is loaded from 01_data, use it
TOP_K = 8                                  # how many examples to export
MAX_SCAN = 300                             # scan first N val rows for speed (CPU friendly)

# ---------- local renderer with reversed meaning ----------
def render_shap_text_inline_rev(exp, *, label_name="", title="SHAP Text Explanation", save_path=None, prob=None):
    """
    Red = positive SHAP (pushes prediction UP -> more toxic)
    Blue = negative SHAP (pushes prediction DOWN -> less toxic)
    """
    import html as _html
    tokens = list(exp.data)
    values = np.array(exp.values, dtype=float)
    max_abs = float(np.max(np.abs(values))) if np.any(values) else 1.0

    def color_for(v):
        alpha = min(abs(v) / (max_abs + 1e-8), 1.0)
        if v >= 0:
            # positive SHAP -> red (pushes up)
            return f"background-color: rgba(255,0,0,{0.15 + 0.6*alpha});"
        else:
            # negative SHAP -> blue (pushes down)
            return f"background-color: rgba(0,120,255,{0.15 + 0.6*alpha});"

    spans = [
        f'<span style="padding:2px 4px; margin:1px; border-radius:4px; {color_for(val)}">'
        f'{_html.escape(str(tok))}</span>'
        for tok, val in zip(tokens, values)
    ]

    legend = """
    <div style="font:14px/1.4 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;">
      <div style="margin-bottom:8px;"><b>Legend</b> — <span style="color:#c00;"><b>red</b></span>: pushes <i>up</i> (increases toxicity), <span style="color:#08f;"><b>blue</b></span>: pushes <i>down</i> (decreases toxicity); intensity ∝ |SHAP|</div>
      <div style="display:flex; gap:12px; align-items:center; margin-bottom:12px;">
        <span style="background:rgba(255,0,0,0.35); padding:4px 8px; border-radius:4px;">push ↑ (more toxic)</span>
        <span style="background:rgba(0,120,255,0.35); padding:4px 8px; border-radius:4px;">pull ↓ (less toxic)</span>
      </div>
    </div>
    """

    prob_line = f'<div style="color:#555; margin-bottom:4px;">Predicted P({_html.escape(label_name)}): <b>{prob:.3f}</b></div>' if prob is not None else ""

    html_doc = f"""<!doctype html>
<html>
<head><meta charset="utf-8" /><title>{_html.escape(title)}</title></head>
<body style="font:16px/1.6 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial; padding:24px;">
  <h2 style="margin:0 0 8px;">{_html.escape(title)}</h2>
  <div style="color:#555; margin-bottom:4px;">Label: <b>{_html.escape(label_name)}</b></div>
  {prob_line}
  <div style="color:#777; margin-bottom:16px;">Max |SHAP|: {max_abs:.4f}</div>
  {legend}
  <div style="border:1px solid #eee; padding:12px; border-radius:8px;">
    {' '.join(spans)}
  </div>
</body>
</html>"""

    # display inline
    display(HTML(html_doc))

    # optional save
    if save_path:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        with open(save_path, "w", encoding="utf-8") as f:
            f.write(html_doc)
        print("✅ Saved SHAP HTML to:", save_path)


# ---------- gather texts & probabilities ----------
if USE_TOP_FROM_VAL:
    scan_df = val_df.head(MAX_SCAN).copy()
    # get probabilities for chosen label
    model.eval()
    with torch.no_grad():
        enc = tokenizer(
            scan_df["comment"].tolist(),
            truncation=True, padding=True, max_length=min(128, cfg.train.max_len), return_tensors="pt"
        ).to(model.device)
        probs_all = torch.sigmoid(model(**enc).logits).cpu().numpy()[:, label_idx]
    scan_df["__prob__"] = probs_all
    chosen = scan_df.sort_values("__prob__", ascending=False).head(TOP_K)[["comment","__prob__"]].reset_index(drop=True)
    texts = chosen["comment"].tolist()
    probs_for_texts = chosen["__prob__"].to_numpy()
    source_note = f"Top {TOP_K} from val_df (out of first {MAX_SCAN} rows) by P({label_to_explain})."
else:
    texts = [
        "I completely disagree with you but let's keep it respectful.",
        "You are an absolute idiot and a disgrace.",
        "I love the way you explained that concept!",
        "This is the dumbest thing I've read.",
        "Thanks for the clarification, appreciate it."
    ][:TOP_K]
    # compute probabilities for display
    with torch.no_grad():
        enc = tokenizer(texts, truncation=True, padding=True, max_length=min(128, cfg.train.max_len), return_tensors="pt").to(model.device)
        probs_for_texts = torch.sigmoid(model(**enc).logits).cpu().numpy()[:, label_idx]
    source_note = "Custom sample texts."

# ---------- render & save each ----------
index_rows = []
for i, (txt, p) in enumerate(zip(texts, probs_for_texts), start=1):
    exps = explainer([txt])
    exp = exps[0]
    out_path = os.path.join(gallery_dir, f"shap_{label_to_explain}_{i:02d}.html")
    render_shap_text_inline_rev(exp, label_name=label_to_explain, save_path=out_path, prob=float(p))
    index_rows.append((i, out_path, float(p), txt[:90] + ("…" if len(txt) > 90 else "")))

# ---------- write simple gallery index ----------
index_html = os.path.join(gallery_dir, "index.html")
html_rows = "\n".join(
    f'<tr><td style="padding:6px 10px;">{i:02d}</td>'
    f'<td style="padding:6px 10px;"><a href="{os.path.basename(path)}" target="_blank">view</a></td>'
    f'<td style="padding:6px 10px;">{p:.3f}</td>'
    f'<td style="padding:6px 10px;">{txt}</td></tr>'
    for (i, path, p, txt) in index_rows
)
with open(index_html, "w", encoding="utf-8") as f:
    f.write(f"""<!doctype html>
<html><head><meta charset="utf-8"><title>SHAP Gallery — {label_to_explain}</title></head>
<body style="font:15px/1.6 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial; padding:20px;">
<h2 style="margin-top:0;">SHAP Gallery — Label: {label_to_explain}</h2>
<div style="color:#666; margin-bottom:12px;">{source_note}</div>
<table style="border-collapse:collapse; border:1px solid #eee;">
<thead><tr style="background:#fafafa;">
<th style="padding:6px 10px; text-align:left;">#</th>
<th style="padding:6px 10px; text-align:left;">Explanation</th>
<th style="padding:6px 10px; text-align:left;">P({label_to_explain})</th>
<th style="padding:6px 10px; text-align:left;">Text (truncated)</th>
</tr></thead>
<tbody>
{html_rows}
</tbody></table>
</body></html>""")

print("✅ Wrote gallery to:", gallery_dir)
print("Open:", index_html)
display(HTML(f'<a href="{index_html}" target="_blank">Open SHAP gallery</a>'))
# Out:
#   0%|          | 0/306 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:12, 12.96s/it]
# <!doctype html>
# <html>
# <head><meta charset="utf-8" /><title>SHAP Text Explanation</title></head>
# <body style="font:16px/1.6 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial; padding:24px;">
#   <h2 style="margin:0 0 8px;">SHAP Text Explanation</h2>
#   <div style="color:#555; margin-bottom:4px;">Label: <b>toxic</b></div>
#   <div style="color:#555; margin-bottom:4px;">Predicted P(toxic): <b>0.000</b></div>
#   <div style="color:#777; margin-bottom:16px;">Max |SHAP|: 0.1170</div>
#
#     <div style="font:14px/1.4 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;">
#       <div style="margin-bottom:8px;"><b>Legend</b> — <span style="color:#c00;"><b>red</b></span>: pushes <i>up</i> (increases toxicity), <span style="color:#08f;"><b>blue</b></span>: pushes <i>down</i> (decreases toxicity); intensity ∝ |SHAP|</div>
#       <div style="display:flex; gap:12px; align-items:center; margin-bottom:12px;">
#         <span style="background:rgba(255,0,0,0.35); padding:4px 8px; border-radius:4px;">push ↑ (more toxic)</span>
#         <span style="background:rgba(0,120,255,0.35); padding:4px 8px; border-radius:4px;">pull ↓ (less toxic)</span>
#       </div>
#     </div>
#
#   <div style="border:1px solid #eee; padding:12px; border-radius:8px;">
#     <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.15000001894582063);"></span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.4071422963884552);">I</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.6103021018155476);"> complete</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.32857961732551094);">ly</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.23947998339051174);"> dis</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.749999948704383);">agree</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.3293283990681019);"> with</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.19415563618118775);"> you</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.4879048084516088);"> but</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.20861813426758974);"> let</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.2542340179545423);">&#x27;</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.19992689099126196);">s</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.18504652322036125);"> keep</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.25000927380104593);"> it</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.7389601186873966);"> respect</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.24169008938056552);">ful</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.4113764662230063);">.</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.15000000149289894);"></span>
#   </div>
# </body>
# </html>
# ✅ Saved SHAP HTML to: ../reports\figs\shap_gallery_toxic\shap_toxic_01.html
#   0%|          | 0/182 [00:00<?, ?it/s]
# <!doctype html>
# <html>
# <head><meta charset="utf-8" /><title>SHAP Text Explanation</title></head>
# <body style="font:16px/1.6 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial; padding:24px;">
#   <h2 style="margin:0 0 8px;">SHAP Text Explanation</h2>
#   <div style="color:#555; margin-bottom:4px;">Label: <b>toxic</b></div>
#   <div style="color:#555; margin-bottom:4px;">Predicted P(toxic): <b>0.986</b></div>
#   <div style="color:#777; margin-bottom:16px;">Max |SHAP|: 0.4052</div>
#
#     <div style="font:14px/1.4 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;">
#       <div style="margin-bottom:8px;"><b>Legend</b> — <span style="color:#c00;"><b>red</b></span>: pushes <i>up</i> (increases toxicity), <span style="color:#08f;"><b>blue</b></span>: pushes <i>down</i> (decreases toxicity); intensity ∝ |SHAP|</div>
#       <div style="display:flex; gap:12px; align-items:center; margin-bottom:12px;">
#         <span style="background:rgba(255,0,0,0.35); padding:4px 8px; border-radius:4px;">push ↑ (more toxic)</span>
#         <span style="background:rgba(0,120,255,0.35); padding:4px 8px; border-radius:4px;">pull ↓ (less toxic)</span>
#       </div>
#     </div>
#
#   <div style="border:1px solid #eee; padding:12px; border-radius:8px;">
#     <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.15000001378932548);"></span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.2788920604093911);">You</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.15497692885270387);"> are</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.189523408759821);"> an</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.15213593549372117);"> </span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.23522983731119324);">absolute</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.7499999851938245);"> idiot</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.16587771057154777);"> and</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.15026574098634257);"> </span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.20129744777849087);">a</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.2944799400429505);"> dis</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.27408209408875445);">grace</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.20120076943848897);">.</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.15);"></span>
#   </div>
# </body>
# </html>
# ✅ Saved SHAP HTML to: ../reports\figs\shap_gallery_toxic\shap_toxic_02.html
#   0%|          | 0/156 [00:00<?, ?it/s]
# <!doctype html>
# <html>
# <head><meta charset="utf-8" /><title>SHAP Text Explanation</title></head>
# <body style="font:16px/1.6 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial; padding:24px;">
#   <h2 style="margin:0 0 8px;">SHAP Text Explanation</h2>
#   <div style="color:#555; margin-bottom:4px;">Label: <b>toxic</b></div>
#   <div style="color:#555; margin-bottom:4px;">Predicted P(toxic): <b>0.000</b></div>
#   <div style="color:#777; margin-bottom:16px;">Max |SHAP|: 0.1158</div>
#
#     <div style="font:14px/1.4 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;">
#       <div style="margin-bottom:8px;"><b>Legend</b> — <span style="color:#c00;"><b>red</b></span>: pushes <i>up</i> (increases toxicity), <span style="color:#08f;"><b>blue</b></span>: pushes <i>down</i> (decreases toxicity); intensity ∝ |SHAP|</div>
#       <div style="display:flex; gap:12px; align-items:center; margin-bottom:12px;">
#         <span style="background:rgba(255,0,0,0.35); padding:4px 8px; border-radius:4px;">push ↑ (more toxic)</span>
#         <span style="background:rgba(0,120,255,0.35); padding:4px 8px; border-radius:4px;">pull ↓ (less toxic)</span>
#       </div>
#     </div>
#
#   <div style="border:1px solid #eee; padding:12px; border-radius:8px;">
#     <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.15000001524165543);"></span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.41108232007267875);">I</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.7499999481806513);"> love</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.4969146914670144);"> the</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.536004084621678);"> way</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.20522222042642294);"> you</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.21327701476490837);"> </span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.5454502877612155);">explain</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.3794022375262018);">ed</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.3152057075501447);"> that</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.42349815418891446);"> concept</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.4457828910270034);">!</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.15000000150814152);"></span>
#   </div>
# </body>
# </html>
# ✅ Saved SHAP HTML to: ../reports\figs\shap_gallery_toxic\shap_toxic_03.html
#   0%|          | 0/156 [00:00<?, ?it/s]
# <!doctype html>
# <html>
# <head><meta charset="utf-8" /><title>SHAP Text Explanation</title></head>
# <body style="font:16px/1.6 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial; padding:24px;">
#   <h2 style="margin:0 0 8px;">SHAP Text Explanation</h2>
#   <div style="color:#555; margin-bottom:4px;">Label: <b>toxic</b></div>
#   <div style="color:#555; margin-bottom:4px;">Predicted P(toxic): <b>0.897</b></div>
#   <div style="color:#777; margin-bottom:16px;">Max |SHAP|: 0.6761</div>
#
#     <div style="font:14px/1.4 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;">
#       <div style="margin-bottom:8px;"><b>Legend</b> — <span style="color:#c00;"><b>red</b></span>: pushes <i>up</i> (increases toxicity), <span style="color:#08f;"><b>blue</b></span>: pushes <i>down</i> (decreases toxicity); intensity ∝ |SHAP|</div>
#       <div style="display:flex; gap:12px; align-items:center; margin-bottom:12px;">
#         <span style="background:rgba(255,0,0,0.35); padding:4px 8px; border-radius:4px;">push ↑ (more toxic)</span>
#         <span style="background:rgba(0,120,255,0.35); padding:4px 8px; border-radius:4px;">pull ↓ (less toxic)</span>
#       </div>
#     </div>
#
#   <div style="border:1px solid #eee; padding:12px; border-radius:8px;">
#     <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.15000000431308516);"></span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.1764268342942444);">This</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.17880137830440512);"> is</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.17526656441047955);"> the</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.7499999911259594);"> dum</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.15628223660046836);">best</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.20354208035022348);"> thing</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.18665767465385788);"> I</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.16733533990588934);">&#x27;</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.16144917723144464);">ve</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.23566507888612886);"> read</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.20174728295577612);">.</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.15);"></span>
#   </div>
# </body>
# </html>
# ✅ Saved SHAP HTML to: ../reports\figs\shap_gallery_toxic\shap_toxic_04.html
# <!doctype html>
# <html>
# <head><meta charset="utf-8" /><title>SHAP Text Explanation</title></head>
# <body style="font:16px/1.6 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial; padding:24px;">
#   <h2 style="margin:0 0 8px;">SHAP Text Explanation</h2>
#   <div style="color:#555; margin-bottom:4px;">Label: <b>toxic</b></div>
#   <div style="color:#555; margin-bottom:4px;">Predicted P(toxic): <b>0.000</b></div>
#   <div style="color:#777; margin-bottom:16px;">Max |SHAP|: 0.1241</div>
#
#     <div style="font:14px/1.4 system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;">
#       <div style="margin-bottom:8px;"><b>Legend</b> — <span style="color:#c00;"><b>red</b></span>: pushes <i>up</i> (increases toxicity), <span style="color:#08f;"><b>blue</b></span>: pushes <i>down</i> (decreases toxicity); intensity ∝ |SHAP|</div>
#       <div style="display:flex; gap:12px; align-items:center; margin-bottom:12px;">
#         <span style="background:rgba(255,0,0,0.35); padding:4px 8px; border-radius:4px;">push ↑ (more toxic)</span>
#         <span style="background:rgba(0,120,255,0.35); padding:4px 8px; border-radius:4px;">pull ↓ (less toxic)</span>
#       </div>
#     </div>
#
#   <div style="border:1px solid #eee; padding:12px; border-radius:8px;">
#     <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.15000002565066425);"></span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.6723397901783577);">Thanks</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.2725782440169456);"> for</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.346742515877133);"> the</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.5471902722875057);"> clar</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.6437238944841895);">ification</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.37438450812256063);">,</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.17355492501077102);"> </span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.7499999516405974);">appreciate</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.20577583419241335);"> it</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(0,120,255,0.3922865757603108);">.</span> <span style="padding:2px 4px; margin:1px; border-radius:4px; background-color: rgba(255,0,0,0.15);"></span>
#   </div>
# </body>
# </html>
# ✅ Saved SHAP HTML to: ../reports\figs\shap_gallery_toxic\shap_toxic_05.html
# ✅ Wrote gallery to: ../reports\figs\shap_gallery_toxic
# Open: ../reports\figs\shap_gallery_toxic\index.html
# <a href="../reports\figs\shap_gallery_toxic\index.html" target="_blank">Open SHAP gallery</a>
